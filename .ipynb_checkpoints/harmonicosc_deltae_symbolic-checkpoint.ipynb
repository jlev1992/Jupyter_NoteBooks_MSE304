# %% [markdown]
# Problem Code: harmonicosc_deltae_symbolic
#
# Solution by Joshua Leveillee
#
# Problem:
#
# <p>
# The quantum-mechanical solution for the ground state energy of this
# system of coupled harmonic oscillators is:
# </p>
# <p>
# $E_g =
# \frac{\hbar}{2}\left(\sqrt{\frac{C}{m}-\frac{2K}{mR^3}}+\sqrt{\frac{C}{m}+\frac{2K}{mR^3}}\right)
# = \frac{\hbar}{2}\left(\sqrt{\omega_0^2-\Delta\omega}+\sqrt{\omega_0^2+\Delta\omega}\right)$.
# </p>
# <p>
# What is the ground-state energy in case there is <b>no</b> Coulomb
# interaction between the two system?
# </p>
# </p>
# <p>
#  $E_g^0 = $ <input data-instavalue="submittedAnswer.matrix1" />
# </p>
# <p>
# The following is not needed to answer this question, but purely for
# your information: In the case the Coulomb interaction between the two systems
# exists, you can use this Taylor expansion:
# </p>
# <p>
# $\sqrt{\omega_0+\Delta\omega}\approx\sqrt{\omega_0}+\frac{1}{2\sqrt{\omega_0}}\Delta\omega-\frac{1}{8\omega_0^{3/2}}\Delta\omega^2$
# </p>
# <p>
# This allows you to show an interesting equation for the interaction energy $\Delta E=E_g - E_g^0$:
# </p>
# <p>
# $\Delta E=E_g - E_g^0=-\hbar\frac{1}{8\omega_0^3}\left(\frac{2K}{m}\right)^2\frac{1}{R^6}$
# </p>
# <p>
# The answer is negative, which means it is an attractive potential, and
# it goes as $R^{−6}$. We use this exact form in the Lennard-Jones
# potential! This is how a simple model of two coupled harmonic
# oscillators can reproduce this form of the Lennard-Jones potential.
# </p>
# <p>
#   <small>
#     Give your answers in symbolic form. You can use the scalar
#     variables <code>hbar</code>, <code>C</code>, and <code>m</code> as defined above. Functions are available
#     like <code>sin()</code>, <code>cos()</code>, <code>atan2()</code>, <code>sqrt()</code>,
#     and <code>log()</code>, as well as the mathematical
#     constants <code>pi</code> and <code>e</code>. The regular
#     arithmetic operators
#     are <code>+</code>, <code>-</code>, <code>*</code>,
#     and <code>/</code>, and
#     <code>x^y</code>
#     means <code>x</code> to the power of <code>y</code>. To write the
# product of two variables, you <i>need</i> to include the
# <code>*</code> symbol.
#   </small>
# </p>
# <p>
#   <small>
#     An example formula is <code>sin(C * m) </code>.
#   </small>
# </p>
#
# Solution:
#
# All terms that rely on the interaction between the systems (seperation $R$ and change in frequency $\Delta \omega$) go to 0. So, the expression for the non-interacting ground state energy is now:
#
# \begin{equation}
# E_g = \frac{\hbar}{2}\left(\sqrt{\frac{C}{m}}+\sqrt{\frac{C}{m}}\right) = \hbar \sqrt{\frac{C}{m}}
# \end{equation}
